# %%
# print("GPU is", "available" if tf.config.experimental.list_physical_devices("GPU") else "NOT AVAILABLE")

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
cd drive/My\ Drive/FAKE_NEWS_DETECTION/DATASET

# %%
from glob import glob
lis = glob('*.csv')
print(lis)

# %%
# !pip install -q tf-models-official==2.7.0

# %%
# !pip install tensorflow_text

# %%
import tensorflow_hub as hub
import tensorflow_text as text 
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
from sklearn.metrics import precision_recall_fscore_support
from official.nlp import optimization

# %%
preprocess_text=hub.KerasLayer("https://tfhub.dev/tensorflow/albert_en_preprocess/3")
encoder=hub.KerasLayer("https://tfhub.dev/tensorflow/albert_en_base/2")

# %%
def create_model():
  text_input = tf.keras.layers.Input(shape=(), dtype=tf.string, name='text')
  text = preprocess_text(text_input)
  result=encoder(text)
  model = tf.keras.Sequential()
  model.add(embedding_model)
  Nl = tf.keras.layers.Dropout(0.1, name="dropout")(result['pooled_output'])
  Nl = tf.keras.layers.Dense(1, activation='sigmoid', name="output")(Nl)

  model= tf.keras.Model(inputs=[text_input],outputs=[Nl])
  model.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=[[tf.keras.metrics.BinaryAccuracy()]])
  return model

# %%
rows=[]
for i in lis:
  df=pd.read_csv(i)
  X_,Y_=df['text'],df['label']
  print(type(X_))
  model=create_model()
  X_ = np.array([np.array(val) for val in X_])
  model.fit(X_, Y_, validation_split=0.1,batch_size=32,epochs=5)
  j_compare=[]
  j_compare.append(i)
  for j in lis:
    df_=pd.read_csv(j)
    X__test = df_['text']
    y__test = df_['label']
    X__test = np.array([np.array(val) for val in X__test])
    # X__test = tf.convert_to_tensor(np.asarray(X__test))
    y=model.predict(X__test)
    y__= [0 if i < 0.5 else 1 for i in y]
    performances = np.asarray(precision_recall_fscore_support(y__test,y__, average='macro'))
    j_compare.append(performances[2])
    # save results
    print(performances)
    print(i+j+"completed")
  rows.append(j_compare)

# %%
import csv
fields=['KAGGLE_DATASET_Jruvika.csv', 'ISOT_FAKE_NEWS_DATASET.csv', 'UTK_FAKE_NEWS_DATASET.csv', 'G_McIntire_FAKE_NEWS_DATASET_.csv', 'LIAR_FAKE_NEWS_DATASET.csv', 'COVID-19_Tweets_FAKE_NEWS_DATASET.csv']

with open('../RESULT/ALBERT_RESULT.csv', 'w') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    write.writerow(fields)
    write.writerows(rows)

# %%
# # ABSTRACT INTRODUCTION-METHOD USE,Methodology, reseach and discussion ,refrences
# <class 'pandas.core.series.Series'>
# Epoch 1/5
# 114/114 [==============================] - 77s 676ms/step - loss: 0.6092 - binary_accuracy: 0.6552 - val_loss: 0.6099 - val_binary_accuracy: 0.6559
# Epoch 2/5
# 114/114 [==============================] - 77s 678ms/step - loss: 0.5974 - binary_accuracy: 0.6753 - val_loss: 0.6120 - val_binary_accuracy: 0.6757
# Epoch 3/5
# 114/114 [==============================] - 77s 677ms/step - loss: 0.5956 - binary_accuracy: 0.6745 - val_loss: 0.6017 - val_binary_accuracy: 0.6609
# Epoch 4/5
# 114/114 [==============================] - 77s 677ms/step - loss: 0.5880 - binary_accuracy: 0.6778 - val_loss: 0.6030 - val_binary_accuracy: 0.6782
# Epoch 5/5
# 114/114 [==============================] - 77s 676ms/step - loss: 0.5796 - binary_accuracy: 0.6962 - val_loss: 0.6001 - val_binary_accuracy: 0.6832
# [0.7158331287709461 0.7052890466631145 0.7000157130991643 None]
# Data_1.csvData_1.csvcompleted
# [0.7076063164506213 0.697885377868557 0.6943069421407597 None]
# Data_1.csvData_2.csvcompleted
# [0.5660026787121173 0.5641954022988506 0.5641514556078391 None]
# Data_1.csvData_3.csvcompleted
# [0.5927336777621309 0.5898203592814372 0.5865733091048921 None]
# Data_1.csvData_4.csvcompleted
# [0.6453082549634274 0.6313952755905512 0.6215533354817918 None]
# Data_1.csvData_5.csvcompleted
# [0.6515813021314106 0.6360410094637224 0.6264672558350328 None]
# Data_1.csvData_6.csvcompleted
# [0.5478151688486029 0.546468862150172 0.5445841301652623 None]
# Data_1.csvData_7.csvcompleted
# [0.5561477555502016 0.5545822840249643 0.5514557868631687 None]
# Data_1.csvData_8.csvcompleted
# [0.40485103727967553 0.49946603641456583 0.32334850172523655 None]
# Data_1.csvTweet_.csvcompleted
# [0.2689920362273579 0.49769782913165267 0.3220417706609832 None]
# Data_1.csvTweet_1.csvcompleted
# [0.23770491803278687 0.49754901960784315 0.32171156893819336 None]
# Data_1.csvTweet_2.csvcompleted
# [0.5093379464052431 0.5002976566780462 0.31214717794854296 None]
# Data_1.csvTweet_3.csvcompleted
# <class 'pandas.core.series.Series'>
# Epoch 1/5
# 469/469 [==============================] - 333s 711ms/step - loss: 0.5800 - binary_accuracy: 0.6971 - val_loss: 0.6134 - val_binary_accuracy: 0.6444
# Epoch 2/5
# 469/469 [==============================] - 327s 698ms/step - loss: 0.5633 - binary_accuracy: 0.7109 - val_loss: 0.5354 - val_binary_accuracy: 0.7279
# Epoch 3/5
# 469/469 [==============================] - 316s 674ms/step - loss: 0.5567 - binary_accuracy: 0.7153 - val_loss: 0.5172 - val_binary_accuracy: 0.7399
# Epoch 4/5
# 469/469 [==============================] - 326s 694ms/step - loss: 0.5471 - binary_accuracy: 0.7267 - val_loss: 0.5421 - val_binary_accuracy: 0.7297
# Epoch 5/5
# 469/469 [==============================] - 316s 673ms/step - loss: 0.5424 - binary_accuracy: 0.7303 - val_loss: 0.5526 - val_binary_accuracy: 0.7069
# [0.7522804517408572 0.7454762113082305 0.7447949217860722 None]
# Data_2.csvData_1.csvcompleted
# [0.7534221147666527 0.7470863871200288 0.7454956913097615 None]
# Data_2.csvData_2.csvcompleted
# [0.6366248097412481 0.6375670498084292 0.6289887852228819 None]
# Data_2.csvData_3.csvcompleted
# [0.6777148276590921 0.6739520958083832 0.6722170699706602 None]
# Data_2.csvData_4.csvcompleted
# [0.6819696969696969 0.6815685039370079 0.68150027578599 None]
# Data_2.csvData_5.csvcompleted
# [0.674522860738255 0.6738958990536277 0.6736027589984934 None]
# Data_2.csvData_6.csvcompleted
# [0.5890691593216872 0.5804538207916727 0.5664420670606634 None]
# Data_2.csvData_7.csvcompleted
# [0.5993689132631144 0.5897569254352348 0.5795903339425639 None]
# Data_2.csvData_8.csvcompleted
# [0.3379391100702576 0.4984856442577031 0.32291741503785876 None]
# Data_2.csvTweet_.csvcompleted
# [0.25510682996602896 0.4957370448179272 0.3211796282815404 None]
# Data_2.csvTweet_1.csvcompleted
# [0.2787437343358396 0.4950542717086835 0.32140435791865163 None]
# Data_2.csvTweet_2.csvcompleted
# [0.5018103126304457 0.5002393959227388 0.33358900514362855 None]
# Data_2.csvTweet_3.csvcompleted
# <class 'pandas.core.series.Series'>
# Epoch 1/5
# 23/23 [==============================] - 15s 659ms/step - loss: 0.7275 - binary_accuracy: 0.5919 - val_loss: 0.6954 - val_binary_accuracy: 0.6000
# Epoch 2/5
# 23/23 [==============================] - 15s 658ms/step - loss: 0.6807 - binary_accuracy: 0.6198 - val_loss: 0.6880 - val_binary_accuracy: 0.6125
# Epoch 3/5
# 23/23 [==============================] - 15s 659ms/step - loss: 0.6394 - binary_accuracy: 0.6379 - val_loss: 0.6618 - val_binary_accuracy: 0.5875
# Epoch 4/5
# 23/23 [==============================] - 15s 658ms/step - loss: 0.6287 - binary_accuracy: 0.6588 - val_loss: 0.6444 - val_binary_accuracy: 0.5875
# Epoch 5/5
# 23/23 [==============================] - 15s 658ms/step - loss: 0.6036 - binary_accuracy: 0.6727 - val_loss: 0.6353 - val_binary_accuracy: 0.6250
# [0.741554468204705 0.7382655283197308 0.7364031961874796 None]
# Data_3.csvData_1.csvcompleted
# [0.7431008995402407 0.7394569265889703 0.7384768982233734 None]
# Data_3.csvData_2.csvcompleted
# [0.6957211870255349 0.6901532567049808 0.6916772150363979 None]
# Data_3.csvData_3.csvcompleted
# [0.7207396784164866 0.7134730538922156 0.7110954102441017 None]
# Data_3.csvData_4.csvcompleted
# [0.6682063021815243 0.6573669291338582 0.6510688646211407 None]
# Data_3.csvData_5.csvcompleted
# [0.6661993988717115 0.6547712933753943 0.6487328876339198 None]
# Data_3.csvData_6.csvcompleted
# [0.7002808531674511 0.6987054346557171 0.6964753344578805 None]
# Data_3.csvData_7.csvcompleted
# [0.6987476298011341 0.6965126464469507 0.6956570369270894 None]
# Data_3.csvData_8.csvcompleted
# [0.48829588014981273 0.4999124649859944 0.32433956221894467 None]
# Data_3.csvTweet_.csvcompleted
# [0.2689920362273579 0.49769782913165267 0.3220417706609832 None]
# Data_3.csvTweet_1.csvcompleted
# [0.23795039775386057 0.4985294117647059 0.3221412733607856 None]
# Data_3.csvTweet_2.csvcompleted
# [0.5014747204737439 0.5000847570030668 0.31747872675393446 None]
# Data_3.csvTweet_3.csvcompleted
# <class 'pandas.core.series.Series'>
# Epoch 1/5
# 94/94 [==============================] - 63s 666ms/step - loss: 0.5639 - binary_accuracy: 0.7239 - val_loss: 0.4898 - val_binary_accuracy: 0.7964
# Epoch 2/5
# 94/94 [==============================] - 63s 666ms/step - loss: 0.5334 - binary_accuracy: 0.7462 - val_loss: 0.4989 - val_binary_accuracy: 0.8024
# Epoch 3/5
# 94/94 [==============================] - 63s 666ms/step - loss: 0.5053 - binary_accuracy: 0.7778 - val_loss: 0.4723 - val_binary_accuracy: 0.8114
# Epoch 4/5
# 94/94 [==============================] - 62s 666ms/step - loss: 0.4897 - binary_accuracy: 0.7848 - val_loss: 0.4477 - val_binary_accuracy: 0.8144
# Epoch 5/5
# 94/94 [==============================] - 62s 664ms/step - loss: 0.4849 - binary_accuracy: 0.7871 - val_loss: 0.4691 - val_binary_accuracy: 0.7964
# [0.7100504055471688 0.7017634579426391 0.7000101449988885 None]
# Data_4.csvData_1.csvcompleted
# [0.6938935956328122 0.6870118947494894 0.6842098770227765 None]
# Data_4.csvData_2.csvcompleted
# [0.7782290266658876 0.773639846743295 0.77536494148872 None]
# Data_4.csvData_3.csvcompleted
# [0.8103815883684405 0.8083832335329342 0.8080743108686181 None]
# Data_4.csvData_4.csvcompleted
# [0.6013850443702679 0.6004094488188977 0.5996616788083717 None]
# Data_4.csvData_5.csvcompleted
# [0.6226384422287863 0.6210567823343849 0.6198310288024759 None]
# Data_4.csvData_6.csvcompleted
# [0.7856041357189153 0.7355962554215895 0.7173880416060137 None]
# Data_4.csvData_7.csvcompleted
# [0.7901673288731776 0.7381473776415197 0.7258607511533974 None]
# Data_4.csvData_8.csvcompleted
# [0.30789285714285713 0.45291491596638656 0.31726059077052454 None]
# Data_4.csvTweet_.csvcompleted
# [0.3078279905044125 0.4550974556489263 0.3174790369867082 None]
# Data_4.csvTweet_1.csvcompleted
# [0.2926704966641957 0.4451593137254902 0.31205464672822164 None]
# Data_4.csvTweet_2.csvcompleted
# [0.5081427258877643 0.5039645204396084 0.40628825469024676 None]
# Data_4.csvTweet_3.csvcompleted
# <class 'pandas.core.series.Series'>
# Epoch 1/5
# 36/36 [==============================] - 24s 669ms/step - loss: 0.6681 - binary_accuracy: 0.6279 - val_loss: 0.6709 - val_binary_accuracy: 0.6508
# Epoch 2/5
# 36/36 [==============================] - 24s 667ms/step - loss: 0.6521 - binary_accuracy: 0.6252 - val_loss: 0.6357 - val_binary_accuracy: 0.6429
# Epoch 3/5
# 36/36 [==============================] - 24s 666ms/step - loss: 0.6318 - binary_accuracy: 0.6429 - val_loss: 0.6190 - val_binary_accuracy: 0.6825
# Epoch 4/5
# 36/36 [==============================] - 24s 667ms/step - loss: 0.6302 - binary_accuracy: 0.6561 - val_loss: 0.6030 - val_binary_accuracy: 0.7302
# Epoch 5/5
# 36/36 [==============================] - 24s 666ms/step - loss: 0.6196 - binary_accuracy: 0.6658 - val_loss: 0.5791 - val_binary_accuracy: 0.7302
# [0.6880599563500929 0.6870394246593119 0.6859902876813375 None]
# Data_5.csvData_1.csvcompleted
# [0.6871941251717417 0.6856902559173375 0.6850577146725452 None]
# Data_5.csvData_2.csvcompleted
# [0.7600239175071639 0.7207662835249042 0.7234015572294504 None]
# Data_5.csvData_3.csvcompleted
# [0.7806660712883724 0.7461077844311377 0.7380441582493263 None]
# Data_5.csvData_4.csvcompleted
# [0.6957779443949097 0.6947464566929134 0.6941205698399477 None]
# Data_5.csvData_5.csvcompleted
# [0.6906197185728825 0.6904574132492114 0.6903915083328318 None]
# Data_5.csvData_6.csvcompleted
# [0.750701961578452 0.7408534250498062 0.7351397599571836 None]
# Data_5.csvData_7.csvcompleted
# [0.7590194913559165 0.7465235957516698 0.743429154398095 None]
# Data_5.csvData_8.csvcompleted
# [0.28440156550425044 0.4806635154061625 0.31800265016186113 None]
# Data_5.csvTweet_.csvcompleted
# [0.2779800983644058 0.4764005602240896 0.31629403364071723 None]
# Data_5.csvTweet_1.csvcompleted
# [0.26720485804044436 0.4758053221288515 0.31503237336302115 None]
# Data_5.csvTweet_2.csvcompleted
# [0.4902559274350835 0.49690055880741474 0.3670976995767913 None]
# Data_5.csvTweet_3.csvcompleted
# <class 'pandas.core.series.Series'>
# Epoch 1/5
# 143/143 [==============================] - 96s 674ms/step - loss: 0.5817 - binary_accuracy: 0.6939 - val_loss: 0.5325 - val_binary_accuracy: 0.7323
# Epoch 2/5
# 143/143 [==============================] - 96s 672ms/step - loss: 0.5515 - binary_accuracy: 0.7191 - val_loss: 0.5128 - val_binary_accuracy: 0.7461
# Epoch 3/5
# 143/143 [==============================] - 96s 673ms/step - loss: 0.5380 - binary_accuracy: 0.7266 - val_loss: 0.5255 - val_binary_accuracy: 0.7362
# Epoch 4/5
# 143/143 [==============================] - 96s 673ms/step - loss: 0.5257 - binary_accuracy: 0.7384 - val_loss: 0.4898 - val_binary_accuracy: 0.7835
# Epoch 5/5
# 143/143 [==============================] - 96s 672ms/step - loss: 0.5175 - binary_accuracy: 0.7443 - val_loss: 0.4816 - val_binary_accuracy: 0.7835
